# %% [markdown]
# Tên: Nguyễn Minh Quân<br>
# MSSV: 20098151

# %%
import pandas as pd
import firebase_admin
from firebase_admin import firestore, credentials

cred = credentials.Certificate('iuh-20098151-firebase-adminsdk-wyb05-41ce913fdb.json')
app = firebase_admin.initialize_app(cred)
dbFireStore = firestore.client()

# %%
queryResults = list(dbFireStore.collection(u'tbl-20098151').limit(5).stream())
listQueryResult = list(map(lambda x : x.to_dict(), queryResults))
df = pd.DataFrame(listQueryResult)
df
# Out:
#   POSTALCODE TERRITORY  QTR_ID             CUSTOMERNAME  ORDERDATE  \
# 0     N 5804      EMEA       3             Herkku Gifts   9/3/2004
# 1      97561       NaN       3         Gift Ideas Corp.   9/3/2003
# 2       2060      APAC       3  Anna's Decorations, Ltd  9/11/2003
# 3      42100      EMEA       2      L'ordine Souveniers  5/10/2005
# 4      28034      EMEA       4    Euro Shopping Channel  12/2/2003
#
#    ORDERLINENUMBER CONTACTFIRSTNAME    SALES   STATUS   PRODUCTLINE  ...  \
# 0                3           Veysel  8272.34  Shipped  Vintage Cars  ...
# 1                2              Dan  3155.58  Shipped   Motorcycles  ...
# 2               14             Anna  5418.88  Shipped  Classic Cars  ...
# 3                3         Maurizio  5642.83  Shipped        Planes  ...
# 4                8            Diego  3930.40  Shipped  Classic Cars  ...
#
#    MONTH_ID  ADDRESSLINE2 STATE YEAR_ID MSRP CONTACTLASTNAME    CATEGORY  \
# 0         9           NaN   NaN    2004  168          Oeztan   Furniture
# 1         9           NaN    CT    2003   62           Lewis   Furniture
# 2         9      Level 15   NSW    2003  169          O'Hara   Furniture
# 3         5           NaN   NaN    2005  118          Moroni  Technology
# 4        12           NaN   NaN    2003  194          Freyre   Furniture
#
#    PRODUCTCODE    COUNTRY QUANTITYORDERED
# 0     S18_2795     Norway              43
# 1     S18_3782        USA              47
# 2     S18_3232  Australia              32
# 3    S700_2834      Italy              41
# 4     S12_1099      Spain              20
#
# [5 rows x 27 columns]

# %%
queryResults = list(dbFireStore.collection(u'tbl-20098151').where(u'COUNTRY', u'==', 'USA').stream())
listQueryResult = list(map(lambda x : x.to_dict(), queryResults))
df = pd.DataFrame(listQueryResult)
df
# Out:
#       QUANTITYORDERED  PRICEEACH  TERRITORY  ORDERLINENUMBER   ORDERDATE  \
# 0                  47      67.14        NaN                2    9/3/2003
# 1                  45      49.81        NaN               12   12/2/2003
# 2                  37     100.00        NaN                4  11/14/2003
# 3                  48      42.26        NaN                5   11/4/2004
# 4                  47      77.24        NaN                8  11/14/2003
# ...               ...        ...        ...              ...         ...
# 999                20      48.62        NaN               15  11/14/2003
# 1000               49      49.28        NaN                6   9/12/2003
# 1001               21      64.66        NaN                8  10/10/2003
# 1002               41     100.00        NaN                8   1/29/2004
# 1003               50      61.22        NaN                7   5/11/2004
#
#                      CUSTOMERNAME CONTACTFIRSTNAME           CITY   STATUS  \
# 0                Gift Ideas Corp.              Dan       Glendale  Shipped
# 1              Muscle Machine Inc             Jeff            NYC  Shipped
# 2             Mini Creations Ltd.           Wing C    New Bedford  Shipped
# 3                FunGiftIdeas.com          Violeta    New Bedford  Shipped
# 4             Mini Creations Ltd.           Wing C    New Bedford  Shipped
# ...                           ...              ...            ...      ...
# 999           Mini Creations Ltd.           Wing C    New Bedford  Shipped
# 1000     Signal Collectibles Ltd.              Sue       Brisbane  Shipped
# 1001     Corporate Gift Ideas Co.            Julie  San Francisco  Shipped
# 1002  West Coast Collectables Co.            Steve        Burbank  Shipped
# 1003    The Sharp Gifts Warehouse              Sue       San Jose  Shipped
#
#        PRODUCTLINE  ... MONTH_ID  ADDRESSLINE2 STATE YEAR_ID  MSRP  \
# 0      Motorcycles  ...        9           NaN    CT    2003    62
# 1     Classic Cars  ...       12     Suite 400    NY    2003    50
# 2            Ships  ...       11           NaN    MA    2003   100
# 3     Classic Cars  ...       11           NaN    MA    2004    50
# 4     Vintage Cars  ...       11           NaN    MA    2003    87
# ...            ...  ...      ...           ...   ...     ...   ...
# 999         Trains  ...       11           NaN    MA    2003    58
# 1000  Vintage Cars  ...        9           NaN    CA    2003    44
# 1001   Motorcycles  ...       10           NaN    CA    2003    62
# 1002  Vintage Cars  ...        1           NaN    CA    2004    99
# 1003  Vintage Cars  ...        5           NaN    CA    2004    68
#
#      CONTACTLASTNAME         CATEGORY  PRODUCTCODE COUNTRY QTR_ID
# 0              Lewis        Furniture     S18_3782     USA      3
# 1              Young  Office Supplies     S24_1628     USA      4
# 2                Tam       Technology    S700_3505     USA      4
# 3            Benitez  Office Supplies     S24_1628     USA      4
# 4                Tam        Furniture     S18_4522     USA      4
# ...              ...              ...          ...     ...    ...
# 999              Tam      Accessories     S50_1514     USA      4
# 1000          Taylor  Office Supplies     S24_2022     USA      3
# 1001           Brown        Furniture     S18_3782     USA      4
# 1002        Thompson        Furniture     S18_3320     USA      1
# 1003           Frick  Office Supplies     S32_4289     USA      2
#
# [1004 rows x 27 columns]

# %%
queryResults = list(dbFireStore.collection(u'tbl-20098151').where(u'YEAR_ID', u'==', 2005).where(u'QTR_ID', u'==', 1).stream())
list(map(lambda x : x.to_dict(), queryResults))
df = pd.DataFrame(listQueryResult)
df
# Out:
#       QUANTITYORDERED  PRICEEACH  TERRITORY  ORDERLINENUMBER   ORDERDATE  \
# 0                  47      67.14        NaN                2    9/3/2003
# 1                  45      49.81        NaN               12   12/2/2003
# 2                  37     100.00        NaN                4  11/14/2003
# 3                  48      42.26        NaN                5   11/4/2004
# 4                  47      77.24        NaN                8  11/14/2003
# ...               ...        ...        ...              ...         ...
# 999                20      48.62        NaN               15  11/14/2003
# 1000               49      49.28        NaN                6   9/12/2003
# 1001               21      64.66        NaN                8  10/10/2003
# 1002               41     100.00        NaN                8   1/29/2004
# 1003               50      61.22        NaN                7   5/11/2004
#
#                      CUSTOMERNAME CONTACTFIRSTNAME           CITY   STATUS  \
# 0                Gift Ideas Corp.              Dan       Glendale  Shipped
# 1              Muscle Machine Inc             Jeff            NYC  Shipped
# 2             Mini Creations Ltd.           Wing C    New Bedford  Shipped
# 3                FunGiftIdeas.com          Violeta    New Bedford  Shipped
# 4             Mini Creations Ltd.           Wing C    New Bedford  Shipped
# ...                           ...              ...            ...      ...
# 999           Mini Creations Ltd.           Wing C    New Bedford  Shipped
# 1000     Signal Collectibles Ltd.              Sue       Brisbane  Shipped
# 1001     Corporate Gift Ideas Co.            Julie  San Francisco  Shipped
# 1002  West Coast Collectables Co.            Steve        Burbank  Shipped
# 1003    The Sharp Gifts Warehouse              Sue       San Jose  Shipped
#
#        PRODUCTLINE  ... MONTH_ID  ADDRESSLINE2 STATE YEAR_ID  MSRP  \
# 0      Motorcycles  ...        9           NaN    CT    2003    62
# 1     Classic Cars  ...       12     Suite 400    NY    2003    50
# 2            Ships  ...       11           NaN    MA    2003   100
# 3     Classic Cars  ...       11           NaN    MA    2004    50
# 4     Vintage Cars  ...       11           NaN    MA    2003    87
# ...            ...  ...      ...           ...   ...     ...   ...
# 999         Trains  ...       11           NaN    MA    2003    58
# 1000  Vintage Cars  ...        9           NaN    CA    2003    44
# 1001   Motorcycles  ...       10           NaN    CA    2003    62
# 1002  Vintage Cars  ...        1           NaN    CA    2004    99
# 1003  Vintage Cars  ...        5           NaN    CA    2004    68
#
#      CONTACTLASTNAME         CATEGORY  PRODUCTCODE COUNTRY QTR_ID
# 0              Lewis        Furniture     S18_3782     USA      3
# 1              Young  Office Supplies     S24_1628     USA      4
# 2                Tam       Technology    S700_3505     USA      4
# 3            Benitez  Office Supplies     S24_1628     USA      4
# 4                Tam        Furniture     S18_4522     USA      4
# ...              ...              ...          ...     ...    ...
# 999              Tam      Accessories     S50_1514     USA      4
# 1000          Taylor  Office Supplies     S24_2022     USA      3
# 1001           Brown        Furniture     S18_3782     USA      4
# 1002        Thompson        Furniture     S18_3320     USA      1
# 1003           Frick  Office Supplies     S32_4289     USA      2
#
# [1004 rows x 27 columns]
